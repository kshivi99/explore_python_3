# %% [markdown]
# # Advanced Numbers

# %% [markdown]
# ## Hexadecimals

# %% [markdown]
# #### 0xF - 1111 (its a nibble), 0xFF - 1111 1111 (its a byte)

# %%
hex(255)
# Out:
# '0xff'

# %%
hex(3)
# Out:
# '0x3'

# %%
hex(236)
# Out:
# '0xec'

# %% [markdown]
# ## Binary

# %%
bin(255)
# Out:
# '0b11111111'

# %% [markdown]
# ## Round & Absolute

# %%
abs(-345)
# Out:
# 345

# %%
abs(56.2)
# Out:
# 56.2

# %%
round(8.6)
# Out:
# 9
