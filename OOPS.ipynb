# %% [markdown]
# ### Class attribute vs Instance attribute

# %%
class Student:
    gender = "male"   # class attribute

# %%
s1 = Student()
print(s1.gender)
# Out:
# male

# %%
s2 = Student()
s2.gender = "female"
print(s2.gender)   # Overrides class attribute
# Out:
# female

# %% [markdown]
# ### Using self for creating variables with class scope

# %%
# self.name will have its scope within the class, where as name declared inside a function will have its scope 
# just within the function

# %%
class Student:
    def load(self, name):
        self.name = name
        age = 10
        
    def prin(self):
        print(self.name)
        print(age)
        
s1 = Student()
s1.load("aman")
s1.prin()
# Out:
# aman
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e9eb1d0cbbaf> in <module>
#      10 s1 = Student()
#      11 s1.load("aman")
# ---> 12 s1.prin()
#
# <ipython-input-6-e9eb1d0cbbaf> in prin(self)
#       6     def prin(self):
#       7         print(self.name)
# ----> 8         print(age)
#       9
#      10 s1 = Student()
#
# NameError: name 'age' is not defined

# %% [markdown]
# ### the __init__ method : Python's own constructor

# %%
class Human:
    # The init takes arguments at the inception of object. We can then make those arguments as instance attributes.
    def __init__(self, name, age):
        self.name = name
        self.age = age
        
    def pri(self):
        print(self.name)
        print(self.age)

# %%
s1 = Human("aman", 26)
s1.pri()
# Out:
# aman
# 26

# %%
s2 = Human("golu", 28)
s2.pri()
# Out:
# golu
# 28
